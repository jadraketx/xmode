# %%
import pandas as pd
import sqlalchemy as db
from sqlalchemy.orm import sessionmaker
import pickle
from utils import Base, Venue, Venue_category, Device
import datetime
import pytz
from tzwhere import tzwhere

# %%
#connect to db
engine = db.create_engine('postgresql://jadrake:taacc4ever@localhost/xmode')
Session = sessionmaker(bind=engine)
session = Session()

# %%
#load pickle files
aux_tables_dir = "/Users/jadrake/Documents/Misc/COVID/Mobility/xmode/db_code/tables/"

with open(aux_tables_dir + 'xmode_venue_masterlist.pickle','rb') as f:
    venues_tab = pickle.load(f)

# %%
venues_tab
# Out:
# {'public-storage': ['Businesses and Services', 'Storage and Moving'],
#  '76-gas-station': ['Travel', 'Gas Stations'],
#  'auto-value': ['Automotive', 'Car Parts and Accessories'],
#  'mcdonalds': ['Food and Dining', 'Fast Food', 'Burgers'],
#  'chick-fil-a': ['Food and Dining', 'Fast Food', 'Chicken'],
#  '7-eleven': ['Travel', 'Gas Stations', 'Convenience Store'],
#  'chrysler': ['Automotive', 'Car Dealers and Leasing', 'Midscale Vehicles'],
#  'chase': ['Businesses and Services',
#   'Financial Services',
#   'Banking and Finance',
#   'Banks and Credit Unions'],
#  'malls-shopping-centers': ['Retail', 'Shopping Centers and Malls'],
#  'chevrolet': ['Automotive', 'Car Dealers and Leasing', 'Midscale Vehicles'],
#  'shell': ['Travel', 'Gas Stations'],
#  'sunoco': ['Travel', 'Gas Stations'],
#  'airports': ['Transportation', 'Airports'],
#  'dmv': ['Community and Government', 'Government Departments and Agencies'],
#  'la-quinta-inn': ['Travel', 'Lodging', 'Economy Hotels'],
# ...

# %%
category = ''
temp = session.query(Venue).filter(Venue.venue_category.any(name=category)).all()
b_list = [x.name for x in temp]
comp = set()
for l in venues_tab:
    v_cats = venues_tab[l]
    if category in v_cats:
        comp.add(l)
if len(b_list) != len(comp):
    print("Lists of different lengths")
c = 0
for l in comp:
    if l in b_list:
        c = c + 1
print("Matches " + str(c) + '/' + str(len(b_list)))
# Out:
# Matches 114255/114255

# %%
venue = 'lexus'
temp = session.query(Venue_category).filter(Venue_category.venue.any(name=venue)).all()
c_list = [x.name for x in temp]
print(c_list)
venues_tab[venue]
# Out:
# ['Automotive', 'Car Dealers and Leasing', 'Luxury Vehicles']
# ['Automotive', 'Car Dealers and Leasing', 'Luxury Vehicles']

# %%
v_name_to_id = {}
c = 1
for venue in session.query(Venue).order_by(Venue.id):
    print(str(venue.id) + "\t" + venue.name)
    v_name_to_id[venue.name] = venue.id
    c = c + 1
    if c == 10:
        break
# Out:
# 1	public-storage
# 2	76-gas-station
# 3	auto-value
# 4	mcdonalds
# 5	chick-fil-a
# 6	7-eleven
# 7	chrysler
# 8	chase
# 9	malls-shopping-centers

# %%
tzwhere = tzwhere.tzwhere()

# %%
tab = pd.read_csv("/Users/jadrake/Documents/Misc/COVID/Mobility/xmode/filtered/part-00000-b6931cd9-5e48-47fe-adf0-70f983cd4630-c000.csv", escapechar="\\", index_col=0)

# %%
test = pd.to_datetime(tab['location_at'], unit='s')

# %%
t = test.iloc[0]
lat = tab['latitude'].iloc[0]
lng = tab['longitude'].iloc[0]

# %%
tzwhere.tzNameAt(lat,lng)
# Out:
# 'America/Chicago'
